# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("data.csv")
df
# Out:
#    emp_id         name  age  department         designation        salary  \
# 0     101  Amit Sharma   28          IT   Software Engineer  55000.000000
# 1     102   Riya Verma   32          HR          HR Manager  60000.000000
# 2     103  Rahul Mehta   26          IT   Backend Developer  55857.142857
# 3     104   Sneha Iyer   35     Finance          Accountant  65000.000000
# 4     105  Arjun Singh   29       Sales     Sales Executive  45000.000000
# 5     106   Neha Gupta   31          IT  Frontend Developer  52000.000000
# 6     107   Vikram Rao   38  Operations  Operations Manager  72000.000000
# 7     108   Pooja Nair   38          HR        HR Executive  42000.000000
#
#    experience       city
# 0           4  Bangalore
# 1           8      Delhi
# 2           3       Pune
# 3          10    Chennai
# 4           5     Mumbai
# 5           6  Bangalore
# 6          14  Hyderabad
# 7           2      Kochi

# %%
plt.plot(df["experience"], df["salary"])
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.show()

# %%
df1 =  df["age"].value_counts()
df1
# Out:
# age
# 38    2
# 32    1
# 28    1
# 26    1
# 35    1
# 29    1
# 31    1
# Name: count, dtype: int64

# %%
plt.bar(df1.index, df1.values,figsize(10,4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 plt.bar(df1.index, df1.values,figsize(10,4))
#       2 plt.show()
#
# NameError: name 'figsize' is not defined

# %%
df.head(1)
# Out:
#    emp_id         name  age department        designation   salary  \
# 0     101  Amit Sharma   28         IT  Software Engineer  55000.0
#
#    experience       city
# 0           4  Bangalore

# %%
df2 = df["city"].value_counts()
plt.bar(df2.index, df2.values)
plt.show()

# %%
import seaborn as sb
sb.scatterplot(data=df, x="experience", y="salary",hue="department")
# Out:
# <Axes: xlabel='experience', ylabel='salary'>
