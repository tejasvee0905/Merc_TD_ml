# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("bugatti-fkp-hommage-3840x2160-25202.jpg")

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5, 5), 0)

edges = cv2.Canny(blur, 100, 200)



plt.figure(figsize=(12,6))

plt.subplot(1,4,1)
plt.imshow(image_rgb)
plt.title("Original")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(blur, cmap='gray')
plt.title("Blur")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(edges, cmap='gray')
plt.title("Edges")
plt.axis("off")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("mercedes-benz-amg-3840x2160-16850.jpg")

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5, 5), 0)

edges = cv2.Canny(blur, 100, 200)



plt.figure(figsize=(12,6))

plt.subplot(1,4,1)
plt.imshow(image_rgb)
plt.title("Original")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(blur, cmap='gray')
plt.title("Blur")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(edges, cmap='gray')
plt.title("Edges")
plt.axis("off")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("sample-pan-card.jpg")

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5, 5), 0)

edges = cv2.Canny(blur, 100, 200)



plt.figure(figsize=(12,6))

plt.subplot(1,4,1)
plt.imshow(image_rgb)
plt.title("Original")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(blur, cmap='gray')
plt.title("Blur")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(edges, cmap='gray')
plt.title("Edges")
plt.axis("off")

plt.show()

# %%
# !pip install pytesseract

import pytesseract

image = cv2.imread("sample-pan-card.jpg")
extracted_text = pytesseract.image_to_string(image)

print("Extracted Text:")
print(extracted_text)
# Out:
# ...
# Extracted Text:
# staex faast @f ua war
# INCOME TAX DEPARTMENT bi GOVT. OF INDIA
#
# eared Cea BT sas =
# Permanent Account Number Card
# ABCDE1234F ae
# IE;
# ‘ava / Name ani. —
# APPLICANT NAME ol
#
# ‘fare a1 ATH / Father's Name
# APPLICANT'S FATHER NAME
#
# Sen cht ah | =>
#
# Date of Birth
#
# 01/06/1995 FEAT | Signature

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("Screenshot 2026-02-02 102904.png")

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5, 5), 0)

edges = cv2.Canny(blur, 100, 200)



plt.figure(figsize=(12,6))

plt.subplot(1,4,1)
plt.imshow(image_rgb)
plt.title("Original")
plt.axis("off")

plt.subplot(1,4,2)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(blur, cmap='gray')
plt.title("Blur")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(edges, cmap='gray')
plt.title("Edges")
plt.axis("off")

plt.show()

# %%
image = cv2.imread("Screenshot 2026-02-02 102904.png")
extracted_text = pytesseract.image_to_string(image)

print("Extracted Text:")
print(extracted_text)
# Out:
# Extracted Text:
#
#
#
#
#
# ~
#
# —_ g ps
# %, vy
# —_ & ‘BN.
# GOVERNMENT OF INDIA “*0NAA8
#
# SAMARTH SHARMA
# Male
# 20-06-1986
#
# 1234 5678 9012
# MY AADHAAR

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
results = model('ss1.png', show=True)
for r in results:
  for box in r.boxes:
    print(
         "Class:", r.names[int(box.cls)],
          "Confidence:", float(box.conf),
          "x, y cordinates", box.xyxy   # x1,y1,x2,y2
    )
# Out:
# image 1/1 /content/ss1.png: 480x640 1 car, 2 cups, 1 banana, 1 book, 193.0ms
# Speed: 3.7ms preprocess, 193.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Class: banana Confidence: 0.8492133617401123 x, y cordinates tensor([[271.5615,  16.9290, 350.2422,  76.7518]])
# Class: cup Confidence: 0.7061188220977783 x, y cordinates tensor([[205.6579, 101.9750, 273.6215, 178.2851]])
# Class: car Confidence: 0.6661221385002136 x, y cordinates tensor([[213.2110, 276.8152, 325.8280, 352.0005]])
# Class: cup Confidence: 0.36128905415534973 x, y cordinates tensor([[223.5321, 223.1215, 272.1572, 265.0666]])
# Class: book Confidence: 0.32462605834007263 x, y cordinates tensor([[ 19.1938, 191.2334, 208.3257, 264.2142]])
